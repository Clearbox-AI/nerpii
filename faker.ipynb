# %%
import pandas as pd
pd.pandas.set_option('display.max_columns', None)

from ner_functions import get_entities_confidence_score
from faker_functions import *
from faker import Faker

# %%
synth = pd.read_csv('dataset/PersonalInfo.csv')

# %%
synth
# Out:
#     first_name  last_name                   company_name  \
# 0        James       Butt              Benton, John B Jr
# 1    Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2          Art     Venere            Chemel, James L Cpa
# 3        Lenna   Paprocki         Feltz Printing Service
# 4      Donette     Foller            Printing Dimensions
# ..         ...        ...                            ...
# 495    Brittni  Gillaspie                    Inner Label
# 496    Raylene      Kampa                     Hermar Inc
# 497        Flo   Bookamer   Simonton Howe & Schneider Pc
# 498       Jani      Biddy  Warehouse Office & Paper Prod
# 499   Chauncey     Motley     Affiliated With Travelodge
#
#                   address         city      county state    zip        phone1  \
# 0      6649 N Blue Gum St  New Orleans     Orleans    LA  70116  504-621-8927
# 1     4 B Blue Ridge Blvd     Brighton  Livingston    MI  48116  810-292-9388
# 2    8 W Cerritos Ave #54   Bridgeport  Gloucester    NJ   8014  856-636-8749
# 3             639 Main St    Anchorage   Anchorage    AK  99501  907-385-4412
# 4            34 Center St     Hamilton      Butler    OH  45011  513-570-1893
# ..                    ...          ...         ...   ...    ...           ...
# 495            67 Rv Cent        Boise         Ada    ID  83709  208-709-1235
# 496        2 Sw Nyberg Rd      Elkhart     Elkhart    IN  46514  574-499-1454
# 497       89992 E 15th St     Alliance   Box Butte    NE  69301  308-726-2182
# 498      61556 W 20th Ave      Seattle        King    WA  98104  206-711-6498
# 499        63 E Aurora Dr      Orlando      Orange    FL  32804  407-413-4842
#
#            phone2                          email  \
# 0    504-845-1427                jbutt@gmail.com
# 1    810-374-9840  josephine_darakjy@darakjy.org
# 2    856-264-4130                 art@venere.org
# 3    907-921-2010          lpaprocki@hotmail.com
# 4    513-549-4561         donette.foller@cox.net
# ..            ...                            ...
# 495  208-206-9848       bgillaspie@gillaspie.com
# 496  574-330-1884               rkampa@kampa.org
# 497  308-250-6987           flo.bookamer@cox.net
# 498  206-395-6284               jbiddy@yahoo.com
# 499  407-557-8857        chauncey_motley@aol.com
#
#                                          web
# 0               http://www.bentonjohnbjr.com
# 1           http://www.chanayjeffreyaesq.com
# 2             http://www.chemeljameslcpa.com
# 3        http://www.feltzprintingservice.com
# 4          http://www.printingdimensions.com
# ..                                       ...
# 495                http://www.innerlabel.com
# 496                 http://www.hermarinc.com
# 497   http://www.simontonhoweschneiderpc.com
# 498  http://www.warehouseofficepaperprod.com
# 499  http://www.affiliatedwithtravelodge.com
#
# [500 rows x 12 columns]

# %%
list_entities = get_entities_confidence_score('dataset/PersonalInfo.csv')

# %%
list_entities
# Out:
# {'first_name': {'entity': 'PERSON', 'confidence_score': 0.544},
#  'last_name': {'entity': 'PERSON', 'confidence_score': 0.276},
#  'company_name': {'entity': 'PERSON', 'confidence_score': 0.314},
#  'address': {'entity': 'ADDRESS', 'confidence_score': 0.532},
#  'city': {'entity': 'LOCATION', 'confidence_score': 0.672},
#  'county': {'entity': 'LOCATION', 'confidence_score': 0.544},
#  'state': {'entity': 'LOCATION', 'confidence_score': 0.484},
#  'zip': {'entity': 'ZIPCODE', 'confidence_score': 1.0},
#  'phone1': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.89},
#  'phone2': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.918},
#  'email': {'entity': 'EMAIL_ADDRESS', 'confidence_score': 1.0},
#  'web': {'entity': 'URL', 'confidence_score': 0.996}}

# %%
get_synthetic_dataset(synth, list_entities)
# Out:
# Column address synthesized.
# Column phone1 synthesized.
# Column phone2 synthesized.
# Column email synthesized.
# Column first_name synthesized.
# Column last_name synthesized.
# Column city synthesized.
# Column state synthesized.
# Column web synthesized.
# Column zip synthesized.
# Column company_name not synthesized.
# Column county not synthesized.
#       first_name last_name                   company_name  \
# 0        Brandon    Garner              Benton, John B Jr
# 1         Kelsey      Mays          Chanay, Jeffrey A Esq
# 2           Alex   Baldwin            Chemel, James L Cpa
# 3         Dennis    Horton         Feltz Printing Service
# 4          Erica   Schmidt            Printing Dimensions
# ..           ...       ...                            ...
# 495     Danielle    Garcia                    Inner Label
# 496       Rhonda   Johnson                     Hermar Inc
# 497       Brooke     Brown   Simonton Howe & Schneider Pc
# 498  Christopher   Simmons  Warehouse Office & Paper Prod
# 499         Jeff    Hughes     Affiliated With Travelodge
#
#                             address               city      county state  \
# 0        8215 Greene Cape Suite 875     Lake Derekport     Orleans    VI
# 1     8452 Dalton Highway Suite 868  North Carlosshire  Livingston    AR
# 2         060 Jensen Spurs Apt. 173        Ronaldhaven  Gloucester    CO
# 3     63169 Thomas Mission Apt. 297       Patrickmouth   Anchorage    VT
# 4         844 Amber Roads Suite 279          Perryside      Butler    WI
# ..                              ...                ...         ...   ...
# 495                392 Jeffery Lane        North Laura         Ada    KY
# 496      366 Hannah Square Apt. 546          Allenland     Elkhart    ND
# 497       774 Silva Route Suite 399       Angelicafurt   Box Butte    AZ
# 498  29048 Lucas Junctions Apt. 922    Jacquelineshire        King    NY
# 499             71576 Little Street     West Juliestad      Orange    GU
#
#        zip                 phone1                phone2  \
# 0    93522      515-529-6921x5594          487.159.4629
# 1    62606             7902639718            4894705842
# 2    73910     992-369-0363x40336  001-513-578-9633x698
# 3    77784           164-243-6543    312.255.1466x07647
# 4    22459          (584)484-2347          839-655-7320
# ..     ...                    ...                   ...
# 495  13796    +1-748-639-8362x697    720-580-3679x95035
# 496  19817  001-514-112-5431x5488         (000)804-1014
# 497  42676          (282)214-6538      001-497-240-0230
# 498  59516           913.343.2598    266-463-8243x38535
# 499  15197             0863124355   (635)366-4886x24466
#
#                        email                          web first_name_gender
# 0         teresa44@gmail.com           http://pierce.biz/              male
# 1           xhorne@gmail.com         http://santiago.org/            female
# 2    kevinsantiago@yahoo.com     https://www.stanley.com/              male
# 3      brownashley@yahoo.com       https://www.gomez.com/           unknown
# 4     melendezryan@gmail.com        https://www.shah.com/            female
# ..                       ...                          ...               ...
# 495    brianmorris@gmail.com     https://www.hammond.org/            female
# 496         tmoyer@yahoo.com  http://www.moore-west.info/           unknown
# 497   sandraharris@gmail.com      https://www.adkins.biz/           unknown
# 498     hillsteven@gmail.com            http://craig.com/              male
# 499        jay88@hotmail.com          https://jordan.com/              male
#
# [500 rows x 13 columns]

# %%
us_addresses= pd.read_csv("dataset/list_of_real_usa_addresses.csv")

# %%
us_addresses_entities = get_entities_confidence_score("dataset/list_of_real_usa_addresses.csv")

# %%
us_addresses_entities
# Out:
# {'address': {'entity': 'ADDRESS', 'confidence_score': 0.6153846153846154},
#  'city': {'entity': 'LOCATION', 'confidence_score': 0.5384615384615384},
#  'state': {'entity': 'LOCATION', 'confidence_score': 0.6794871794871795},
#  'zip': {'entity': 'ZIPCODE', 'confidence_score': 1.0}}

# %%
get_synthetic_dataset(us_addresses, us_addresses_entities)
# Out:
# Column address synthesized.
# Column city synthesized.
# Column state synthesized.
# Column zip synthesized.
#                            address            city state    zip
# 0      0463 Maureen Road Suite 813   New Brianview    RI  94106
# 1      411 Franklin Neck Suite 103       Hollytown    MI  94060
# 2     524 Callahan Creek Suite 463     Diazchester    FL  38052
# 3               849 Kimberly Coves  South Kimberly    MS  73071
# 4                 8751 James Spurs    Nataliemouth    MT  19541
# ..                             ...             ...   ...    ...
# 229  612 Norton Overpass Suite 305   North Michael    ID  10814
# 230      491 Laurie Ferry Apt. 306     Arianahaven    MN  53967
# 231       568 Garza Hills Apt. 494     Michaelfort    DC  08592
# 232            77675 Jennifer Fork     Kristenbury    FM  35450
# 233    21529 Evelyn Drive Apt. 772    Lake Jeffrey    AL  81249
#
# [234 rows x 4 columns]

# %%
df_creditNumber = pd.read_csv("dataset/1-MB-Test.csv")

# %%
df_creditNumber
# Out:
#       First and Last Name          SSN   Credit Card Number
# 0                     NaN          NaN         Visa MC AMEX
# 1           Robert Aragon  489-36-8350  4929-3813-3266-4295
# 2           Ashley Borden  514-14-8905  5370-4638-8881-3020
# 3           Thomas Conley  690-05-5315  4916-4811-5814-8111
# 4             Susan Davis  421-37-1396  4916-4034-9269-8783
# ...                   ...          ...                  ...
# 10551        Albert Iorio  322-84-2303  4916-6734-7572-5037
# 10552     Charles Jackson  646-44-9083  5218-0144-2703-9288
# 10553     Teresa Kaminski  465-73-5044  5399-0706-4128-0200
# 10554            Tim Lowe  044-34-6976  5144-8691-2776-1130
# 10555     Monte Mceachern  477-36-0304  5527-1247-5046-7802
#
# [10556 rows x 3 columns]

# %%
df_creditNumber['First and Last Name'].fillna('- -', inplace=True)
df_creditNumber['First and Last Name'].reset_index(drop=True, inplace=True)

# %%
lista_nomi = []
for i in df_creditNumber['First and Last Name']:
        lista_nomi.append(i.split())

# %%
nomi = []
cognomi = [] 
for i in lista_nomi:
     nomi.append(i[0])
     cognomi.append(i[1])

# %%
nomi
# Out:
# ['-',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  ...]

# %%
df_creditNumber['first_name'] = pd.Series(nomi)
df_creditNumber['last_name'] = pd.Series(cognomi)

# %%
df_creditNumber = df_creditNumber.drop('First and Last Name', axis = 1)

# %%
df_creditNumber.to_csv('dataset/1-MB-test-modified.csv', index=False)

# %%
df_creditNumber = pd.read_csv('dataset/1-MB-test-modified.csv')

# %%
df_creditNumber
# Out:
#                SSN   Credit Card Number first_name  last_name
# 0              NaN         Visa MC AMEX          -          -
# 1      489-36-8350  4929-3813-3266-4295     Robert     Aragon
# 2      514-14-8905  5370-4638-8881-3020     Ashley     Borden
# 3      690-05-5315  4916-4811-5814-8111     Thomas     Conley
# 4      421-37-1396  4916-4034-9269-8783      Susan      Davis
# ...            ...                  ...        ...        ...
# 10551  322-84-2303  4916-6734-7572-5037     Albert      Iorio
# 10552  646-44-9083  5218-0144-2703-9288    Charles    Jackson
# 10553  465-73-5044  5399-0706-4128-0200     Teresa   Kaminski
# 10554  044-34-6976  5144-8691-2776-1130        Tim       Lowe
# 10555  477-36-0304  5527-1247-5046-7802      Monte  Mceachern
#
# [10556 rows x 4 columns]

# %%
list_credit_entities = get_entities_confidence_score('dataset/1-MB-test-modified.csv')

# %%
list_credit_entities
# Out:
# {'SSN': {'entity': 'US_SSN', 'confidence_score': 0.918},
#  'Credit Card Number': {'entity': 'CREDIT_CARD_NUMBER',
#   'confidence_score': 1.0},
#  'first_name': {'entity': 'PERSON', 'confidence_score': 0.9},
#  'last_name': {'entity': 'PERSON', 'confidence_score': 0.484}}

# %%
get_synthetic_dataset(df_creditNumber, list_credit_entities)
# Out:
# Column first_name synthesized.
# Column last_name synthesized.
# Column Credit Card Number synthesized.
# Column SSN synthesized.
#                SSN Credit Card Number first_name  last_name first_name_gender
# 0      625-49-2269      4733911104117      Kevin      Colon           unknown
# 1      511-35-3470       630441343963      Malik      Frost              male
# 2      298-73-4065    345470422801166     Kendra  Rasmussen     mostly_female
# 3      643-35-5910     30206907475989       Kyle     Thomas              male
# 4      128-22-4901   4025116269490857     Monica    Herrera            female
# ...            ...                ...        ...        ...               ...
# 10551  485-65-0365       502004571688    Jeffery       Rich              male
# 10552  847-73-9561    376988579517295       Ryan    Coleman              male
# 10553  234-48-2209   3500167966533610     Tracey   Santiago            female
# 10554  415-15-6928      4156849299272  Nathaniel     Palmer              male
# 10555  353-32-6360     30149213398265      Jacob      Simon              male
#
# [10556 rows x 5 columns]

# %%
full_noia = pd.read_csv('dataset/full-foia-contacts.csv')

# %%
full_noia['Name'].fillna('- -', inplace = True)

# %%
full_noia
# Out:
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department             Name  \
# 0         Department of Agriculture  Gregory Bridges
# 1         Department of Agriculture              - -
# 2         Department of Agriculture    William Allen
# 3         Department of Agriculture      Tonya Woods
# 4         Department of Agriculture              - -
# ..                              ...              ...
# 742  Department of Veterans Affairs              - -
# 743  Department of Veterans Affairs      James Horan
# 744  Department of Veterans Affairs    Laurie Karnay
# 745  Department of Veterans Affairs              - -
# 746  Department of Veterans Affairs              - -
#
#                              Title                Room Number  \
# 0                     FOIA Officer  AG Stop 0202, Room 3521-S
# 1    FOIA Requester Service Center                        NaN
# 2              FOIA Public Liaison  AG Stop 0202, Room 3521-S
# 3                    FOIA Director                    Unit 50
# 4    FOIA Requester Service Center                        NaN
# ..                             ...                        ...
# 742  FOIA Requester Service Center                        NaN
# 743            FOIA Public Liaison                        NaN
# 744                 FOIA Team Lead              (005R1C) VACO
# 745  FOIA Requester Service Center                        NaN
# 746            FOIA Public Liaison                        NaN
#
#                    Street Address        City State    Zip Code  \
# 0    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 1                             NaN         NaN   NaN         NaN
# 2    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 3                 4700 River Road   Riverdale    MD  20737-1232
# 4                             NaN         NaN   NaN         NaN
# ..                            ...         ...   ...         ...
# 742                           NaN         NaN   NaN         NaN
# 743                           NaN         NaN   NaN         NaN
# 744        810 Vermont Avenue, NW  Washington    DC       20420
# 745                           NaN         NaN   NaN         NaN
# 746                           NaN         NaN   NaN         NaN
#
#           Telephone             Fax                        Email Address  \
# 0    (202) 720-2498  (202) 690-3767                    AMS.FOIA@USDA.gov
# 1    (202) 720-2498             NaN                                  NaN
# 2    (202) 720-2498             NaN                    AMS.FOIA@USDA.gov
# 3    (301) 851-4102  (301) 734-5941  mailto:tonya.g.woods@aphis.usda.gov
# 4    (301) 851-4102  (301) 734-5941   mailto:foia.officer@aphis.usda.gov
# ..              ...             ...                                  ...
# 742             NaN             NaN                                  NaN
# 743             NaN             NaN                                  NaN
# 744  (202) 632-7465  (202) 632-7581                                  NaN
# 745  (202) 632-7600             NaN                                  NaN
# 746  (202) 632-7600             NaN                                  NaN
#
#                                                Website  \
# 0               http://www.ams.usda.gov/about-ams/foia
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                            http://www.foia.va.gov/
# 745                                                NaN
# 746                                                NaN
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    * Please mail requests to FOIA.Officer@aphis.u...
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
# [747 rows x 15 columns]

# %%
lista_nomi = []
for i in full_noia['Name']:
        lista_nomi.append(i.split())

# %%
for i in lista_nomi:
    if len(i) < 2:
        i.append('-')

# %%
nomi = []
cognomi = [] 
for i in lista_nomi:
     nomi.append(i[0])
     cognomi.append(i[1])

# %%
full_noia['first_name'] = pd.Series(nomi)
full_noia['last_name'] = pd.Series(cognomi)

# %%
full_noia
# Out:
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department             Name  \
# 0         Department of Agriculture  Gregory Bridges
# 1         Department of Agriculture              - -
# 2         Department of Agriculture    William Allen
# 3         Department of Agriculture      Tonya Woods
# 4         Department of Agriculture              - -
# ..                              ...              ...
# 742  Department of Veterans Affairs              - -
# 743  Department of Veterans Affairs      James Horan
# 744  Department of Veterans Affairs    Laurie Karnay
# 745  Department of Veterans Affairs              - -
# 746  Department of Veterans Affairs              - -
#
#                              Title                Room Number  \
# 0                     FOIA Officer  AG Stop 0202, Room 3521-S
# 1    FOIA Requester Service Center                        NaN
# 2              FOIA Public Liaison  AG Stop 0202, Room 3521-S
# 3                    FOIA Director                    Unit 50
# 4    FOIA Requester Service Center                        NaN
# ..                             ...                        ...
# 742  FOIA Requester Service Center                        NaN
# 743            FOIA Public Liaison                        NaN
# 744                 FOIA Team Lead              (005R1C) VACO
# 745  FOIA Requester Service Center                        NaN
# 746            FOIA Public Liaison                        NaN
#
#                    Street Address        City State    Zip Code  \
# 0    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 1                             NaN         NaN   NaN         NaN
# 2    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 3                 4700 River Road   Riverdale    MD  20737-1232
# 4                             NaN         NaN   NaN         NaN
# ..                            ...         ...   ...         ...
# 742                           NaN         NaN   NaN         NaN
# 743                           NaN         NaN   NaN         NaN
# 744        810 Vermont Avenue, NW  Washington    DC       20420
# 745                           NaN         NaN   NaN         NaN
# 746                           NaN         NaN   NaN         NaN
#
#           Telephone             Fax                        Email Address  \
# 0    (202) 720-2498  (202) 690-3767                    AMS.FOIA@USDA.gov
# 1    (202) 720-2498             NaN                                  NaN
# 2    (202) 720-2498             NaN                    AMS.FOIA@USDA.gov
# 3    (301) 851-4102  (301) 734-5941  mailto:tonya.g.woods@aphis.usda.gov
# 4    (301) 851-4102  (301) 734-5941   mailto:foia.officer@aphis.usda.gov
# ..              ...             ...                                  ...
# 742             NaN             NaN                                  NaN
# 743             NaN             NaN                                  NaN
# 744  (202) 632-7465  (202) 632-7581                                  NaN
# 745  (202) 632-7600             NaN                                  NaN
# 746  (202) 632-7600             NaN                                  NaN
#
#                                                Website  \
# 0               http://www.ams.usda.gov/about-ams/foia
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                            http://www.foia.va.gov/
# 745                                                NaN
# 746                                                NaN
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes first_name last_name
# 0                                                  NaN    Gregory   Bridges
# 1                                                  NaN          -         -
# 2                                                  NaN    William     Allen
# 3                                                  NaN      Tonya     Woods
# 4    * Please mail requests to FOIA.Officer@aphis.u...          -         -
# ..                                                 ...        ...       ...
# 742                                                NaN          -         -
# 743                                                NaN      James     Horan
# 744                                                NaN     Laurie    Karnay
# 745                                                NaN          -         -
# 746                                                NaN          -         -
#
# [747 rows x 17 columns]

# %%
full_noia = full_noia.drop('Name', axis = 1)

# %%
full_noia.to_csv('dataset/full-noia-contacts-modified.csv', index=False)

# %%
full_noia = pd.read_csv('dataset/full-noia-contacts-modified.csv')

# %%
list_full_entities = get_entities_confidence_score('dataset/full-noia-contacts-modified.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 list_full_entities = get_entities_confidence_score('dataset/full-noia-contacts-modified.csv')
#
# File ~/Documents/clearbox_repo/clearbox-ner/ner_functions.py:549, in get_entities_confidence_score(df_input_path)
#     528 def get_entities_confidence_score(df_input_path: pd.DataFrame) -> Dict:
#     529     """
#     530     Take as input a dataframe and
#     531     applies ner_presidio function and the ner_organization_entity function on the dataframe.
#    (...)
#     547         which the entity associated to the column and its confidence score are reported.
#     548     """
# --> 549     dict_global_entities = ner_presidio(df_input_path)
#     550     dict_global_entities = ner_organization_entity(df_input_path, dict_global_entities)
#     552     for col in dict_global_entities:
#
# File ~/Documents/clearbox_repo/clearbox-ner/ner_functions.py:459, in ner_presidio(df_input_path, data_sample)
#     457 addresses_recognizer = add_address_entity()
#     458 analyzer = set_analyzer(addresses_recognizer)
# --> 459 analyzer_results = get_analyzer_results(df_input, analyzer)
#     461 dict_global_entities = {}
#     462 list_of_df_cols = list(df_input.columns)
#
# File ~/Documents/clearbox_repo/clearbox-ner/ner_functions.py:102, in get_analyzer_results(df_input, analyzer)
#      84 def get_analyzer_results(df_input: pd.DataFrame, analyzer: BatchAnalyzerEngine) -> List:
#      85     """
#      86     Assign entities to each record in each columns in a pandas dataframe.
#      87     An analyzer analyzes a pandas dataframe by first converting it to json.
#    (...)
#     100         A list that contains the results of the analyzer.
#     101     """
# --> 102     analyzer_results = list(analyzer.analyze_dict(df_input.to_dict(orient="list"), language="en"))
#     104     return analyzer_results
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/presidio_analyzer/batch_analyzer_engine.py:116, in BatchAnalyzerEngine.analyze_dict(self, input_dict, language, keys_to_skip, **kwargs)
#     106     results = self.analyze_dict(
#     107         input_dict=value,
#     108         language=language,
#    (...)
#     111         **kwargs,
#     112     )
#     113 elif isinstance(value, Iterable):
#     114     # Recursively iterate nested dicts
# --> 116     results: List[List[RecognizerResult]] = self.analyze_iterator(
#     117         texts=value,
#     118         language=language,
#     119         context=specific_context,
#     120         **kwargs,
#     121     )
#     122 else:
#     123     raise ValueError(f"type {type(value)} is unsupported.")
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/presidio_analyzer/batch_analyzer_engine.py:52, in BatchAnalyzerEngine.analyze_iterator(self, texts, language, **kwargs)
#      45 nlp_artifacts_batch: Iterator[
#      46     Tuple[str, NlpArtifacts]
#      47 ] = self.analyzer_engine.nlp_engine.process_batch(
#      48     texts=texts, language=language
#      49 )
#      51 list_results = []
# ---> 52 for text, nlp_artifacts in nlp_artifacts_batch:
#      53     results = self.analyzer_engine.analyze(
#      54         text=str(text), nlp_artifacts=nlp_artifacts, language=language, **kwargs
#      55     )
#      57     list_results.append(results)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/presidio_analyzer/nlp_engine/spacy_nlp_engine.py:56, in SpacyNlpEngine.process_batch(self, texts, language, as_tuples)
#      54 texts = (str(text) for text in texts)
#      55 docs = self.nlp[language].pipe(texts, as_tuples=as_tuples)
# ---> 56 for doc in docs:
#      57     yield doc.text, self._doc_to_nlp_artifact(doc, language)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/language.py:1589, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1587     for pipe in pipes:
#    1588         docs = pipe(docs)
# -> 1589 for doc in docs:
#    1590     yield doc
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1651, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "Pipe",
#    (...)
#    1648     kwargs: Mapping[str, Any],
#    1649 ) -> Iterator["Doc"]:
#    1650     if hasattr(proc, "pipe"):
# -> 1651         yield from proc.pipe(docs, **kwargs)
#    1652     else:
#    1653         # We added some args for pipe that __call__ doesn't expect.
#    1654         kwargs = dict(kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/transition_parser.pyx:233, in pipe()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1600, in minibatch(items, size)
#    1598 while True:
#    1599     batch_size = next(size_)
# -> 1600     batch = list(itertools.islice(items, int(batch_size)))
#    1601     if len(batch) == 0:
#    1602         break
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1651, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "Pipe",
#    (...)
#    1648     kwargs: Mapping[str, Any],
#    1649 ) -> Iterator["Doc"]:
#    1650     if hasattr(proc, "pipe"):
# -> 1651         yield from proc.pipe(docs, **kwargs)
#    1652     else:
#    1653         # We added some args for pipe that __call__ doesn't expect.
#    1654         kwargs = dict(kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/pipe.pyx:53, in pipe()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1651, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "Pipe",
#    (...)
#    1648     kwargs: Mapping[str, Any],
#    1649 ) -> Iterator["Doc"]:
#    1650     if hasattr(proc, "pipe"):
# -> 1651         yield from proc.pipe(docs, **kwargs)
#    1652     else:
#    1653         # We added some args for pipe that __call__ doesn't expect.
#    1654         kwargs = dict(kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/pipe.pyx:53, in pipe()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1651, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "Pipe",
#    (...)
#    1648     kwargs: Mapping[str, Any],
#    1649 ) -> Iterator["Doc"]:
#    1650     if hasattr(proc, "pipe"):
# -> 1651         yield from proc.pipe(docs, **kwargs)
#    1652     else:
#    1653         # We added some args for pipe that __call__ doesn't expect.
#    1654         kwargs = dict(kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/trainable_pipe.pyx:73, in pipe()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1600, in minibatch(items, size)
#    1598 while True:
#    1599     batch_size = next(size_)
# -> 1600     batch = list(itertools.islice(items, int(batch_size)))
#    1601     if len(batch) == 0:
#    1602         break
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/util.py:1651, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "Pipe",
#    (...)
#    1648     kwargs: Mapping[str, Any],
#    1649 ) -> Iterator["Doc"]:
#    1650     if hasattr(proc, "pipe"):
# -> 1651         yield from proc.pipe(docs, **kwargs)
#    1652     else:
#    1653         # We added some args for pipe that __call__ doesn't expect.
#    1654         kwargs = dict(kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/trainable_pipe.pyx:75, in pipe()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/spacy/pipeline/tok2vec.py:125, in Tok2Vec.predict(self, docs)
#     123     width = self.model.get_dim("nO")
#     124     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 125 tokvecs = self.model.predict(docs)
#     126 batch_id = Tok2VecListener.get_batch_id(docs)
#     127 for listener in self.listeners:
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/with_array.py:38, in forward(model, Xseq, is_train)
#      36     return model.layers[0](Xseq, is_train)
#      37 else:
# ---> 38     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/with_array.py:73, in _list_forward(model, Xs, is_train)
#      71 lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      72 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 73 Yf, get_dXf = layer(Xf, is_train)
#      75 def backprop(dYs: ListXd) -> ListXd:
#      76     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/expand_window.py:23, in forward(model, X, is_train)
#      21     return _expand_window_ragged(model, X)
#      22 else:
# ---> 23     return _expand_window_floats(model, X)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/thinc/layers/expand_window.py:31, in _expand_window_floats(model, X)
#      29 nW = model.attrs["window_size"]
#      30 if len(X) > 0:
# ---> 31     Y = model.ops.seq2col(X, nW)
#      32 else:
#      33     assert len(X) == 0
#
# KeyboardInterrupt:

# %%
list_full_entities
# Out:
# {'Agency': {'entity': 'ORGANIZATION', 'confidence_score': 0.876},
#  'Department': {'entity': 'ORGANIZATION', 'confidence_score': 1.0},
#  'Title': {'entity': 'PERSON', 'confidence_score': 0.334},
#  'Room Number': {'entity': 'ORGANIZATION', 'confidence_score': 0.156},
#  'Street Address': None,
#  'City': {'entity': 'LOCATION', 'confidence_score': 0.32},
#  'State': None,
#  'Zip Code': {'entity': 'ZIPCODE', 'confidence_score': 1.0},
#  'Telephone': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.902},
#  'Fax': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.32},
#  'Email Address': {'entity': 'EMAIL_ADDRESS', 'confidence_score': 0.38},
#  'Website': {'entity': 'URL', 'confidence_score': 0.326},
#  'Online Request Form': None,
#  'Notes': {'entity': 'ORGANIZATION', 'confidence_score': 0.13},
#  'first_name': {'entity': 'PERSON', 'confidence_score': 0.53},
#  'last_name': None}

# %%
get_synthetic_dataset(full_noia, list_full_entities)
# Out:
# Column Telephone synthesized.
# Column Fax synthesized.
# Column Email Address synthesized.
# Column first_name synthesized.
# Column last_name synthesized.
# Column City synthesized.
# Column Website synthesized.
# Column Zip Code synthesized.
# Column Room Number not synthesized.
# Column Notes not synthesized.
# Column Agency not synthesized.
# Column Department not synthesized.
# Column Title not synthesized.
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department                          Title  \
# 0         Department of Agriculture                   FOIA Officer
# 1         Department of Agriculture  FOIA Requester Service Center
# 2         Department of Agriculture            FOIA Public Liaison
# 3         Department of Agriculture                  FOIA Director
# 4         Department of Agriculture  FOIA Requester Service Center
# ..                              ...                            ...
# 742  Department of Veterans Affairs  FOIA Requester Service Center
# 743  Department of Veterans Affairs            FOIA Public Liaison
# 744  Department of Veterans Affairs                 FOIA Team Lead
# 745  Department of Veterans Affairs  FOIA Requester Service Center
# 746  Department of Veterans Affairs            FOIA Public Liaison
#
#                    Room Number                Street Address  \
# 0    AG Stop 0202, Room 3521-S  1400 Independence Avenue, SW
# 1                          NaN                           NaN
# 2    AG Stop 0202, Room 3521-S  1400 Independence Avenue, SW
# 3                      Unit 50               4700 River Road
# 4                          NaN                           NaN
# ..                         ...                           ...
# 742                        NaN                           NaN
# 743                        NaN                           NaN
# 744              (005R1C) VACO        810 Vermont Avenue, NW
# 745                        NaN                           NaN
# 746                        NaN                           NaN
#
#                    City State Zip Code            Telephone  \
# 0            South Cody    DC    28662        (534)694-5510
# 1           East Leslie   NaN    69607        (836)227-7128
# 2         Port Jesseton    DC    24381         164-118-3398
# 3          Collierhaven    MD    43455  (493)910-7819x74204
# 4       New Sabrinaside   NaN    28785  (035)767-6753x60106
# ..                  ...   ...      ...                  ...
# 742      New Tamaratown   NaN    10909         008-979-4691
# 743          Warnerberg   NaN    68499     001-934-024-8648
# 744           Penashire    DC    61418    (725)710-6437x411
# 745  New Alexanderville   NaN    95947         173-695-3920
# 746           Lake Glen   NaN    66688     636-740-1533x666
#
#                        Fax              Email Address  \
# 0    +1-914-887-5576x19062    randalllauren@yahoo.com
# 1     001-989-752-1837x007        bmcdaniel@gmail.com
# 2            (710)191-6615       boydjoseph@gmail.com
# 3        (207)326-8747x208          zguzman@yahoo.com
# 4       991.031.4932x74590      teresascott@gmail.com
# ..                     ...                        ...
# 742      (273)685-2561x826  sarahstrickland@yahoo.com
# 743       001-491-580-3520       jessicaday@gmail.com
# 744       820.508.5224x082    ayersbrooke@hotmail.com
# 745    +1-528-281-0860x784         bonnie84@gmail.com
# 746    (531)462-0334x22849            ereid@gmail.com
#
#                        Website  \
# 0      https://www.taylor.com/
# 1           https://riley.org/
# 2     http://www.martinez.com/
# 3           https://sharp.com/
# 4        http://www.fritz.net/
# ..                         ...
# 742    http://www.harris.info/
# 743        http://nichols.com/
# 744           http://hall.org/
# 745         http://holmes.org/
# 746  https://www.peterson.com/
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes   first_name last_name  \
# 0                                                  NaN      Brandon      Bell
# 1                                                  NaN        Cathy     Perry
# 2                                                  NaN         John     Stone
# 3                                                  NaN      Jessica    Pierce
# 4    * Please mail requests to FOIA.Officer@aphis.u...      Melissa     Jones
# ..                                                 ...          ...       ...
# 742                                                NaN         Tina   Bradley
# 743                                                NaN         Kyle    Newman
# 744                                                NaN        Jamie      Long
# 745                                                NaN  Christopher    Wright
# 746                                                NaN      Melissa     Woods
#
#     first_name_gender
# 0                male
# 1             unknown
# 2                male
# 3              female
# 4             unknown
# ..                ...
# 742           unknown
# 743              male
# 744            female
# 745           unknown
# 746           unknown
#
# [747 rows x 17 columns]

# %%
df= pd.read_csv("dataset/contact_list_Austin.csv")

# %%
df
# Out:
#                                      Department  First Name       Last Name  \
# 0                                    Department  First Name       Last Name
# 1                        Animal Services Office        Joan  Hamilton-Huber
# 2                        Austin Code Department      Nathan         Brigmon
# 3                        Austin Code Department       Shawn         Lincoln
# 4                      Austin Convention Center       Chris       Hernandez
# ..                                          ...         ...             ...
# 139                    Austin Resource Recovery      Thomas      Montgomery
# 140                    Austin Resource Recovery      Thomas      Montgomery
# 141  Homeland Security and Emergency Management       Angel          Flores
# 142                  Office of the City Auditor       Tyler           Myers
# 143            Austin Transportation Department       Diana          Martin
#
#      Primary Contact                       E-Mail Address  Phone Number  \
# 0    Primary Contact                       E-Mail Address  Phone Number
# 1                NaN  Joan.Hamilton-Huber@austintexas.gov  512-978-0538
# 2                NaN       Nathan.Brigmon@austintexas.gov  512-974-6533
# 3                NaN        Shawn.Lincoln@austintexas.gov  512-974-9029
# 4                NaN      Chris.Hernandez@austintexas.gov  512-404-4031
# ..               ...                                  ...           ...
# 139               No    Thomas.Montgomery@austintexas.gov  512-974-6022
# 140               No    Thomas.Montgomery@austintexas.gov  512-974-6022
# 141              Yes         Angel.flores@austintexas.gov  512-974-0477
# 142              Yes          Tyler.Myers@austintexas.gov  512-974-2015
# 143              Yes         Diana.Martin@austintexas.gov  512-974-4079
#
#           Role
# 0         Role
# 1          NaN
# 2      Liaison
# 3          NaN
# 4      Liaison
# ..         ...
# 139  Publisher
# 140  Publisher
# 141    Liaison
# 142    Liaison
# 143    Liaison
#
# [144 rows x 7 columns]

# %%
list_df_entities = get_entities_confidence_score('dataset/contact_list_Austin.csv')

# %%
list_df_entities
# Out:
# {'Department': {'entity': 'ORGANIZATION',
#   'confidence_score': 0.8611111111111112},
#  'First Name': {'entity': 'PERSON', 'confidence_score': 0.7777777777777778},
#  'Last Name': {'entity': 'PERSON', 'confidence_score': 0.4027777777777778},
#  'Primary Contact': None,
#  'E-Mail Address': {'entity': 'EMAIL_ADDRESS',
#   'confidence_score': 0.8888888888888888},
#  'Phone Number': {'entity': 'PHONE_NUMBER',
#   'confidence_score': 0.8611111111111112},
#  'Role': None}

# %%
get_synthetic_dataset(df, list_df_entities)
# Out:
# Column Phone Number synthesized.
# Column E-Mail Address synthesized.
# Column First Name synthesized.
# Column Last Name synthesized.
# Column Department not synthesized.
#                                      Department First Name Last Name  \
# 0                                    Department      Casey     Clark
# 1                        Animal Services Office   Samantha      Boyd
# 2                        Austin Code Department    Gregory     Clark
# 3                        Austin Code Department      Derek   Shaffer
# 4                      Austin Convention Center    Michael  Marshall
# ..                                          ...        ...       ...
# 139                    Austin Resource Recovery    Jeffrey  Lawrence
# 140                    Austin Resource Recovery     Thomas     Jones
# 141  Homeland Security and Emergency Management     Andrew   Spencer
# 142                  Office of the City Auditor    Michael  Robinson
# 143            Austin Transportation Department    Michele   Sanchez
#
#      Primary Contact             E-Mail Address            Phone Number  \
# 0    Primary Contact         shelby56@gmail.com      (059)632-2714x9372
# 1                NaN      jameslisa@hotmail.com  001-310-813-7700x23658
# 2                NaN       wolfebrett@gmail.com     (173)461-9218x90076
# 3                NaN           ajones@yahoo.com      766.551.9286x65944
# 4                NaN      scastillo@hotmail.com   001-066-732-9165x6185
# ..               ...                        ...                     ...
# 139               No      melanie82@hotmail.com              9115360689
# 140               No   phillipsalas@hotmail.com        907-860-8093x176
# 141              Yes         nathan23@gmail.com            294.542.8449
# 142              Yes  gonzalezcolleen@yahoo.com     (311)325-8720x73990
# 143              Yes     jamesriggs@hotmail.com   +1-718-754-4968x37639
#
#           Role first_name_gender
# 0         Role           unknown
# 1          NaN            female
# 2      Liaison              male
# 3          NaN       mostly_male
# 4      Liaison       mostly_male
# ..         ...               ...
# 139  Publisher              male
# 140  Publisher              male
# 141    Liaison              male
# 142    Liaison       mostly_male
# 143    Liaison            female
#
# [144 rows x 8 columns]

# %%
import gender_guesser.detector as gender

# %%
detector = gender.Detector(case_sensitive=False)

# %%
first_name_gender = []
for name in full_noia['Name']:
    first_name_gender.append(detector.get_gender(name))

# %%
first_name_gender
# Out:
# ['unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown']

# %%
from faker import Faker

if len(list_entities) > 0:
    try:
        faker = Faker()
        loc_cols = [[i, list_entities[i]['entity']] for i in list_entities if list_entities[i] is not None]
        
        adrs = [i[0] for i in loc_cols if i[1] == 'ADDRESS']
        for i in adrs:
            synth[i] = [faker.street_address() for i in range(synth.shape[0])]

        phone = [i[0] for i in loc_cols if i[1] == 'PHONE_NUMBER']
        for i in phone:
            synth[i] = [faker.phone_number() for i in range(synth.shape[0])]

        
    except:
        print('Something went wrong while create fake PIIs')
