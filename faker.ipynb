# %%
import pandas as pd
pd.pandas.set_option('display.max_columns', None)

from ner_functions import get_entities_confidence_score
from faker_functions import *
from faker import Faker

# %%
synth = pd.read_csv('dataset/table_order.csv')

# %%
synth
# Out:
#     first_name  last_name                   company_name  \
# 0        James       Butt              Benton, John B Jr
# 1    Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2          Art     Venere            Chemel, James L Cpa
# 3        Lenna   Paprocki         Feltz Printing Service
# 4      Donette     Foller            Printing Dimensions
# ..         ...        ...                            ...
# 495    Brittni  Gillaspie                    Inner Label
# 496    Raylene      Kampa                     Hermar Inc
# 497        Flo   Bookamer   Simonton Howe & Schneider Pc
# 498       Jani      Biddy  Warehouse Office & Paper Prod
# 499   Chauncey     Motley     Affiliated With Travelodge
#
#                   address         city      county state    zip        phone1  \
# 0      6649 N Blue Gum St  New Orleans     Orleans    LA  70116  504-621-8927
# 1     4 B Blue Ridge Blvd     Brighton  Livingston    MI  48116  810-292-9388
# 2    8 W Cerritos Ave #54   Bridgeport  Gloucester    NJ   8014  856-636-8749
# 3             639 Main St    Anchorage   Anchorage    AK  99501  907-385-4412
# 4            34 Center St     Hamilton      Butler    OH  45011  513-570-1893
# ..                    ...          ...         ...   ...    ...           ...
# 495            67 Rv Cent        Boise         Ada    ID  83709  208-709-1235
# 496        2 Sw Nyberg Rd      Elkhart     Elkhart    IN  46514  574-499-1454
# 497       89992 E 15th St     Alliance   Box Butte    NE  69301  308-726-2182
# 498      61556 W 20th Ave      Seattle        King    WA  98104  206-711-6498
# 499        63 E Aurora Dr      Orlando      Orange    FL  32804  407-413-4842
#
#            phone2                          email  \
# 0    504-845-1427                jbutt@gmail.com
# 1    810-374-9840  josephine_darakjy@darakjy.org
# 2    856-264-4130                 art@venere.org
# 3    907-921-2010          lpaprocki@hotmail.com
# 4    513-549-4561         donette.foller@cox.net
# ..            ...                            ...
# 495  208-206-9848       bgillaspie@gillaspie.com
# 496  574-330-1884               rkampa@kampa.org
# 497  308-250-6987           flo.bookamer@cox.net
# 498  206-395-6284               jbiddy@yahoo.com
# 499  407-557-8857        chauncey_motley@aol.com
#
#                                          web
# 0               http://www.bentonjohnbjr.com
# 1           http://www.chanayjeffreyaesq.com
# 2             http://www.chemeljameslcpa.com
# 3        http://www.feltzprintingservice.com
# 4          http://www.printingdimensions.com
# ..                                       ...
# 495                http://www.innerlabel.com
# 496                 http://www.hermarinc.com
# 497   http://www.simontonhoweschneiderpc.com
# 498  http://www.warehouseofficepaperprod.com
# 499  http://www.affiliatedwithtravelodge.com
#
# [500 rows x 12 columns]

# %%
list_entities = get_entities_confidence_score('dataset/table_order.csv')

# %%
list_entities
# Out:
# {'orderNumber': None,
#  'productCode': None,
#  'quantityOrdered': None,
#  'priceEach': None,
#  'orderLineNumber': None,
#  'orderDate': {'entity': 'DATE_TIME', 'confidence_score': 1.0},
#  'requiredDate': {'entity': 'DATE_TIME', 'confidence_score': 1.0},
#  'shippedDate': {'entity': 'DATE_TIME', 'confidence_score': 0.97},
#  'status': None,
#  'comments': None,
#  'customerNumber': None,
#  'customerName': {'entity': 'ORGANIZATION', 'confidence_score': 0.886},
#  'contactLastName': {'entity': 'PERSON', 'confidence_score': 0.526},
#  'contactFirstName': {'entity': 'PERSON', 'confidence_score': 0.81},
#  'phone': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.592},
#  'addressLine1': {'entity': 'ADDRESS', 'confidence_score': 0.592},
#  'addressLine2': None,
#  'city': {'entity': 'LOCATION', 'confidence_score': 0.79},
#  'state': None,
#  'postalCode': {'entity': 'ZIPCODE', 'confidence_score': 1.0},
#  'country': {'entity': 'LOCATION', 'confidence_score': 1.0},
#  'salesRepEmployeeNumber': None,
#  'creditLimit': None,
#  'productName': None,
#  'productLine': None,
#  'productScale': None,
#  'productVendor': {'entity': 'ORGANIZATION', 'confidence_score': 0.428},
#  'productDescription': None,
#  'quantityInStock': None,
#  'buyPrice': None,
#  'MSRP': None}

# %%
get_synthetic_dataset(synth, list_entities)
# Out:
# Column address synthesized.
# Column phone1 synthesized.
# Column phone2 synthesized.
# Column email synthesized.
# Column first_name synthesized.
# Column last_name synthesized.
# Column city synthesized.
# Column state synthesized.
# Column web synthesized.
# Column zip synthesized.
# Column company_name not synthesized.
# Column county not synthesized.
#       first_name last_name                   company_name  \
# 0        Brandon    Garner              Benton, John B Jr
# 1         Kelsey      Mays          Chanay, Jeffrey A Esq
# 2           Alex   Baldwin            Chemel, James L Cpa
# 3         Dennis    Horton         Feltz Printing Service
# 4          Erica   Schmidt            Printing Dimensions
# ..           ...       ...                            ...
# 495     Danielle    Garcia                    Inner Label
# 496       Rhonda   Johnson                     Hermar Inc
# 497       Brooke     Brown   Simonton Howe & Schneider Pc
# 498  Christopher   Simmons  Warehouse Office & Paper Prod
# 499         Jeff    Hughes     Affiliated With Travelodge
#
#                             address               city      county state  \
# 0        8215 Greene Cape Suite 875     Lake Derekport     Orleans    VI
# 1     8452 Dalton Highway Suite 868  North Carlosshire  Livingston    AR
# 2         060 Jensen Spurs Apt. 173        Ronaldhaven  Gloucester    CO
# 3     63169 Thomas Mission Apt. 297       Patrickmouth   Anchorage    VT
# 4         844 Amber Roads Suite 279          Perryside      Butler    WI
# ..                              ...                ...         ...   ...
# 495                392 Jeffery Lane        North Laura         Ada    KY
# 496      366 Hannah Square Apt. 546          Allenland     Elkhart    ND
# 497       774 Silva Route Suite 399       Angelicafurt   Box Butte    AZ
# 498  29048 Lucas Junctions Apt. 922    Jacquelineshire        King    NY
# 499             71576 Little Street     West Juliestad      Orange    GU
#
#        zip                 phone1                phone2  \
# 0    93522      515-529-6921x5594          487.159.4629
# 1    62606             7902639718            4894705842
# 2    73910     992-369-0363x40336  001-513-578-9633x698
# 3    77784           164-243-6543    312.255.1466x07647
# 4    22459          (584)484-2347          839-655-7320
# ..     ...                    ...                   ...
# 495  13796    +1-748-639-8362x697    720-580-3679x95035
# 496  19817  001-514-112-5431x5488         (000)804-1014
# 497  42676          (282)214-6538      001-497-240-0230
# 498  59516           913.343.2598    266-463-8243x38535
# 499  15197             0863124355   (635)366-4886x24466
#
#                        email                          web first_name_gender
# 0         teresa44@gmail.com           http://pierce.biz/              male
# 1           xhorne@gmail.com         http://santiago.org/            female
# 2    kevinsantiago@yahoo.com     https://www.stanley.com/              male
# 3      brownashley@yahoo.com       https://www.gomez.com/           unknown
# 4     melendezryan@gmail.com        https://www.shah.com/            female
# ..                       ...                          ...               ...
# 495    brianmorris@gmail.com     https://www.hammond.org/            female
# 496         tmoyer@yahoo.com  http://www.moore-west.info/           unknown
# 497   sandraharris@gmail.com      https://www.adkins.biz/           unknown
# 498     hillsteven@gmail.com            http://craig.com/              male
# 499        jay88@hotmail.com          https://jordan.com/              male
#
# [500 rows x 13 columns]

# %%
us_addresses= pd.read_csv("dataset/list_of_real_usa_addresses.csv")

# %%
us_addresses_entities = get_entities_confidence_score("dataset/list_of_real_usa_addresses.csv")

# %%
us_addresses_entities
# Out:
# {'address': {'entity': 'ADDRESS', 'confidence_score': 0.6153846153846154},
#  'city': {'entity': 'LOCATION', 'confidence_score': 0.5384615384615384},
#  'state': {'entity': 'LOCATION', 'confidence_score': 0.6794871794871795},
#  'zip': {'entity': 'ZIPCODE', 'confidence_score': 1.0}}

# %%
get_synthetic_dataset(us_addresses, us_addresses_entities)
# Out:
# Column address synthesized.
# Column city synthesized.
# Column state synthesized.
# Column zip synthesized.
#                            address            city state    zip
# 0      0463 Maureen Road Suite 813   New Brianview    RI  94106
# 1      411 Franklin Neck Suite 103       Hollytown    MI  94060
# 2     524 Callahan Creek Suite 463     Diazchester    FL  38052
# 3               849 Kimberly Coves  South Kimberly    MS  73071
# 4                 8751 James Spurs    Nataliemouth    MT  19541
# ..                             ...             ...   ...    ...
# 229  612 Norton Overpass Suite 305   North Michael    ID  10814
# 230      491 Laurie Ferry Apt. 306     Arianahaven    MN  53967
# 231       568 Garza Hills Apt. 494     Michaelfort    DC  08592
# 232            77675 Jennifer Fork     Kristenbury    FM  35450
# 233    21529 Evelyn Drive Apt. 772    Lake Jeffrey    AL  81249
#
# [234 rows x 4 columns]

# %%
df_creditNumber = pd.read_csv("dataset/1-MB-Test.csv")

# %%
df_creditNumber
# Out:
#       First and Last Name          SSN   Credit Card Number
# 0                     NaN          NaN         Visa MC AMEX
# 1           Robert Aragon  489-36-8350  4929-3813-3266-4295
# 2           Ashley Borden  514-14-8905  5370-4638-8881-3020
# 3           Thomas Conley  690-05-5315  4916-4811-5814-8111
# 4             Susan Davis  421-37-1396  4916-4034-9269-8783
# ...                   ...          ...                  ...
# 10551        Albert Iorio  322-84-2303  4916-6734-7572-5037
# 10552     Charles Jackson  646-44-9083  5218-0144-2703-9288
# 10553     Teresa Kaminski  465-73-5044  5399-0706-4128-0200
# 10554            Tim Lowe  044-34-6976  5144-8691-2776-1130
# 10555     Monte Mceachern  477-36-0304  5527-1247-5046-7802
#
# [10556 rows x 3 columns]

# %%
split_name(df_creditNumber, 'First and Last Name')
# Out:
#                SSN   Credit Card Number first_name last_number
# 0              NaN         Visa MC AMEX          -           -
# 1      489-36-8350  4929-3813-3266-4295     Robert      Aragon
# 2      514-14-8905  5370-4638-8881-3020     Ashley      Borden
# 3      690-05-5315  4916-4811-5814-8111     Thomas      Conley
# 4      421-37-1396  4916-4034-9269-8783      Susan       Davis
# ...            ...                  ...        ...         ...
# 10551  322-84-2303  4916-6734-7572-5037     Albert       Iorio
# 10552  646-44-9083  5218-0144-2703-9288    Charles     Jackson
# 10553  465-73-5044  5399-0706-4128-0200     Teresa    Kaminski
# 10554  044-34-6976  5144-8691-2776-1130        Tim        Lowe
# 10555  477-36-0304  5527-1247-5046-7802      Monte   Mceachern
#
# [10556 rows x 4 columns]

# %%
df_creditNumber['First and Last Name'].fillna('- -', inplace=True)
df_creditNumber['First and Last Name'].reset_index(drop=True, inplace=True)

# %%
lista_nomi = []
for i in df_creditNumber['First and Last Name']:
        lista_nomi.append(i.split())

# %%
nomi = []
cognomi = [] 
for i in lista_nomi:
     nomi.append(i[0])
     cognomi.append(i[1])

# %%
nomi
# Out:
# ['-',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  'Mark',
#  'James',
#  'Albert',
#  'Charles',
#  'Teresa',
#  'Tim',
#  'Monte',
#  'Adriane',
#  'Jerome',
#  'Agnes',
#  'Lynette',
#  'Stacey',
#  'Julie',
#  'Danny',
#  'Jacki',
#  'Thomas',
#  'Mireille',
#  'Lillian',
#  'Gail',
#  'Johnson',
#  'Rebecca',
#  'Robert',
#  'Ashley',
#  'Thomas',
#  'Susan',
#  'Christopher',
#  'Rick',
#  'Victor',
#  'Lisa',
#  'Marjorie',
#  ...]

# %%
df_creditNumber['first_name'] = pd.Series(nomi)
df_creditNumber['last_name'] = pd.Series(cognomi)

# %%
df_creditNumber = df_creditNumber.drop('First and Last Name', axis = 1)

# %%
df_creditNumber.to_csv('dataset/1-MB-test-modified.csv', index=False)

# %%
df_creditNumber = pd.read_csv('dataset/1-MB-test-modified.csv')

# %%
df_creditNumber
# Out:
#                SSN   Credit Card Number first_name  last_name
# 0              NaN         Visa MC AMEX          -          -
# 1      489-36-8350  4929-3813-3266-4295     Robert     Aragon
# 2      514-14-8905  5370-4638-8881-3020     Ashley     Borden
# 3      690-05-5315  4916-4811-5814-8111     Thomas     Conley
# 4      421-37-1396  4916-4034-9269-8783      Susan      Davis
# ...            ...                  ...        ...        ...
# 10551  322-84-2303  4916-6734-7572-5037     Albert      Iorio
# 10552  646-44-9083  5218-0144-2703-9288    Charles    Jackson
# 10553  465-73-5044  5399-0706-4128-0200     Teresa   Kaminski
# 10554  044-34-6976  5144-8691-2776-1130        Tim       Lowe
# 10555  477-36-0304  5527-1247-5046-7802      Monte  Mceachern
#
# [10556 rows x 4 columns]

# %%
list_credit_entities = get_entities_confidence_score('dataset/1-MB-test-modified.csv')

# %%
list_credit_entities
# Out:
# {'SSN': {'entity': 'US_SSN', 'confidence_score': 0.918},
#  'Credit Card Number': {'entity': 'CREDIT_CARD_NUMBER',
#   'confidence_score': 1.0},
#  'first_name': {'entity': 'PERSON', 'confidence_score': 0.9},
#  'last_name': {'entity': 'PERSON', 'confidence_score': 0.484}}

# %%
get_synthetic_dataset(df_creditNumber, list_credit_entities)
# Out:
# Column first_name synthesized.
# Column last_name synthesized.
# Column Credit Card Number synthesized.
# Column SSN synthesized.
#                SSN Credit Card Number first_name  last_name first_name_gender
# 0      625-49-2269      4733911104117      Kevin      Colon           unknown
# 1      511-35-3470       630441343963      Malik      Frost              male
# 2      298-73-4065    345470422801166     Kendra  Rasmussen     mostly_female
# 3      643-35-5910     30206907475989       Kyle     Thomas              male
# 4      128-22-4901   4025116269490857     Monica    Herrera            female
# ...            ...                ...        ...        ...               ...
# 10551  485-65-0365       502004571688    Jeffery       Rich              male
# 10552  847-73-9561    376988579517295       Ryan    Coleman              male
# 10553  234-48-2209   3500167966533610     Tracey   Santiago            female
# 10554  415-15-6928      4156849299272  Nathaniel     Palmer              male
# 10555  353-32-6360     30149213398265      Jacob      Simon              male
#
# [10556 rows x 5 columns]

# %%
full_noia = pd.read_csv('dataset/full-foia-contacts.csv')

# %%
full_noia
# Out:
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department             Name  \
# 0         Department of Agriculture  Gregory Bridges
# 1         Department of Agriculture              NaN
# 2         Department of Agriculture    William Allen
# 3         Department of Agriculture      Tonya Woods
# 4         Department of Agriculture              NaN
# ..                              ...              ...
# 742  Department of Veterans Affairs              NaN
# 743  Department of Veterans Affairs      James Horan
# 744  Department of Veterans Affairs    Laurie Karnay
# 745  Department of Veterans Affairs              NaN
# 746  Department of Veterans Affairs              NaN
#
#                              Title                Room Number  \
# 0                     FOIA Officer  AG Stop 0202, Room 3521-S
# 1    FOIA Requester Service Center                        NaN
# 2              FOIA Public Liaison  AG Stop 0202, Room 3521-S
# 3                    FOIA Director                    Unit 50
# 4    FOIA Requester Service Center                        NaN
# ..                             ...                        ...
# 742  FOIA Requester Service Center                        NaN
# 743            FOIA Public Liaison                        NaN
# 744                 FOIA Team Lead              (005R1C) VACO
# 745  FOIA Requester Service Center                        NaN
# 746            FOIA Public Liaison                        NaN
#
#                    Street Address        City State    Zip Code  \
# 0    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 1                             NaN         NaN   NaN         NaN
# 2    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 3                 4700 River Road   Riverdale    MD  20737-1232
# 4                             NaN         NaN   NaN         NaN
# ..                            ...         ...   ...         ...
# 742                           NaN         NaN   NaN         NaN
# 743                           NaN         NaN   NaN         NaN
# 744        810 Vermont Avenue, NW  Washington    DC       20420
# 745                           NaN         NaN   NaN         NaN
# 746                           NaN         NaN   NaN         NaN
#
#           Telephone             Fax                        Email Address  \
# 0    (202) 720-2498  (202) 690-3767                    AMS.FOIA@USDA.gov
# 1    (202) 720-2498             NaN                                  NaN
# 2    (202) 720-2498             NaN                    AMS.FOIA@USDA.gov
# 3    (301) 851-4102  (301) 734-5941  mailto:tonya.g.woods@aphis.usda.gov
# 4    (301) 851-4102  (301) 734-5941   mailto:foia.officer@aphis.usda.gov
# ..              ...             ...                                  ...
# 742             NaN             NaN                                  NaN
# 743             NaN             NaN                                  NaN
# 744  (202) 632-7465  (202) 632-7581                                  NaN
# 745  (202) 632-7600             NaN                                  NaN
# 746  (202) 632-7600             NaN                                  NaN
#
#                                                Website  \
# 0               http://www.ams.usda.gov/about-ams/foia
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                            http://www.foia.va.gov/
# 745                                                NaN
# 746                                                NaN
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    * Please mail requests to FOIA.Officer@aphis.u...
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
# [747 rows x 15 columns]

# %%
split_name(full_noia, 'Name')
# Out:
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department                          Title  \
# 0         Department of Agriculture                   FOIA Officer
# 1         Department of Agriculture  FOIA Requester Service Center
# 2         Department of Agriculture            FOIA Public Liaison
# 3         Department of Agriculture                  FOIA Director
# 4         Department of Agriculture  FOIA Requester Service Center
# ..                              ...                            ...
# 742  Department of Veterans Affairs  FOIA Requester Service Center
# 743  Department of Veterans Affairs            FOIA Public Liaison
# 744  Department of Veterans Affairs                 FOIA Team Lead
# 745  Department of Veterans Affairs  FOIA Requester Service Center
# 746  Department of Veterans Affairs            FOIA Public Liaison
#
#                    Room Number                Street Address        City  \
# 0    AG Stop 0202, Room 3521-S  1400 Independence Avenue, SW  Washington
# 1                          NaN                           NaN         NaN
# 2    AG Stop 0202, Room 3521-S  1400 Independence Avenue, SW  Washington
# 3                      Unit 50               4700 River Road   Riverdale
# 4                          NaN                           NaN         NaN
# ..                         ...                           ...         ...
# 742                        NaN                           NaN         NaN
# 743                        NaN                           NaN         NaN
# 744              (005R1C) VACO        810 Vermont Avenue, NW  Washington
# 745                        NaN                           NaN         NaN
# 746                        NaN                           NaN         NaN
#
#     State    Zip Code       Telephone             Fax  \
# 0      DC  20250-0273  (202) 720-2498  (202) 690-3767
# 1     NaN         NaN  (202) 720-2498             NaN
# 2      DC  20250-0273  (202) 720-2498             NaN
# 3      MD  20737-1232  (301) 851-4102  (301) 734-5941
# 4     NaN         NaN  (301) 851-4102  (301) 734-5941
# ..    ...         ...             ...             ...
# 742   NaN         NaN             NaN             NaN
# 743   NaN         NaN             NaN             NaN
# 744    DC       20420  (202) 632-7465  (202) 632-7581
# 745   NaN         NaN  (202) 632-7600             NaN
# 746   NaN         NaN  (202) 632-7600             NaN
#
#                            Email Address  \
# 0                      AMS.FOIA@USDA.gov
# 1                                    NaN
# 2                      AMS.FOIA@USDA.gov
# 3    mailto:tonya.g.woods@aphis.usda.gov
# 4     mailto:foia.officer@aphis.usda.gov
# ..                                   ...
# 742                                  NaN
# 743                                  NaN
# 744                                  NaN
# 745                                  NaN
# 746                                  NaN
#
#                                                Website  \
# 0               http://www.ams.usda.gov/about-ams/foia
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                            http://www.foia.va.gov/
# 745                                                NaN
# 746                                                NaN
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes first_name last_number
# 0                                                  NaN    Gregory     Bridges
# 1                                                  NaN          -           -
# 2                                                  NaN    William       Allen
# 3                                                  NaN      Tonya       Woods
# 4    * Please mail requests to FOIA.Officer@aphis.u...          -           -
# ..                                                 ...        ...         ...
# 742                                                NaN          -           -
# 743                                                NaN      James       Horan
# 744                                                NaN     Laurie      Karnay
# 745                                                NaN          -           -
# 746                                                NaN          -           -
#
# [747 rows x 16 columns]

# %%
lista_nomi = []
for i in full_noia['Name']:
        lista_nomi.append(i.split())

# %%
for i in lista_nomi:
    if len(i) < 2:
        i.append('-')

# %%
nomi = []
cognomi = [] 
for i in lista_nomi:
     nomi.append(i[0])
     cognomi.append(i[1])

# %%
full_noia['first_name'] = pd.Series(nomi)
full_noia['last_name'] = pd.Series(cognomi)

# %%
full_noia
# Out:
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department             Name  \
# 0         Department of Agriculture  Gregory Bridges
# 1         Department of Agriculture              - -
# 2         Department of Agriculture    William Allen
# 3         Department of Agriculture      Tonya Woods
# 4         Department of Agriculture              - -
# ..                              ...              ...
# 742  Department of Veterans Affairs              - -
# 743  Department of Veterans Affairs      James Horan
# 744  Department of Veterans Affairs    Laurie Karnay
# 745  Department of Veterans Affairs              - -
# 746  Department of Veterans Affairs              - -
#
#                              Title                Room Number  \
# 0                     FOIA Officer  AG Stop 0202, Room 3521-S
# 1    FOIA Requester Service Center                        NaN
# 2              FOIA Public Liaison  AG Stop 0202, Room 3521-S
# 3                    FOIA Director                    Unit 50
# 4    FOIA Requester Service Center                        NaN
# ..                             ...                        ...
# 742  FOIA Requester Service Center                        NaN
# 743            FOIA Public Liaison                        NaN
# 744                 FOIA Team Lead              (005R1C) VACO
# 745  FOIA Requester Service Center                        NaN
# 746            FOIA Public Liaison                        NaN
#
#                    Street Address        City State    Zip Code  \
# 0    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 1                             NaN         NaN   NaN         NaN
# 2    1400 Independence Avenue, SW  Washington    DC  20250-0273
# 3                 4700 River Road   Riverdale    MD  20737-1232
# 4                             NaN         NaN   NaN         NaN
# ..                            ...         ...   ...         ...
# 742                           NaN         NaN   NaN         NaN
# 743                           NaN         NaN   NaN         NaN
# 744        810 Vermont Avenue, NW  Washington    DC       20420
# 745                           NaN         NaN   NaN         NaN
# 746                           NaN         NaN   NaN         NaN
#
#           Telephone             Fax                        Email Address  \
# 0    (202) 720-2498  (202) 690-3767                    AMS.FOIA@USDA.gov
# 1    (202) 720-2498             NaN                                  NaN
# 2    (202) 720-2498             NaN                    AMS.FOIA@USDA.gov
# 3    (301) 851-4102  (301) 734-5941  mailto:tonya.g.woods@aphis.usda.gov
# 4    (301) 851-4102  (301) 734-5941   mailto:foia.officer@aphis.usda.gov
# ..              ...             ...                                  ...
# 742             NaN             NaN                                  NaN
# 743             NaN             NaN                                  NaN
# 744  (202) 632-7465  (202) 632-7581                                  NaN
# 745  (202) 632-7600             NaN                                  NaN
# 746  (202) 632-7600             NaN                                  NaN
#
#                                                Website  \
# 0               http://www.ams.usda.gov/about-ams/foia
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                            http://www.foia.va.gov/
# 745                                                NaN
# 746                                                NaN
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes first_name last_name
# 0                                                  NaN    Gregory   Bridges
# 1                                                  NaN          -         -
# 2                                                  NaN    William     Allen
# 3                                                  NaN      Tonya     Woods
# 4    * Please mail requests to FOIA.Officer@aphis.u...          -         -
# ..                                                 ...        ...       ...
# 742                                                NaN          -         -
# 743                                                NaN      James     Horan
# 744                                                NaN     Laurie    Karnay
# 745                                                NaN          -         -
# 746                                                NaN          -         -
#
# [747 rows x 17 columns]

# %%
full_noia = full_noia.drop('Name', axis = 1)

# %%
full_noia.to_csv('dataset/full-noia-contacts-modified.csv', index=False)

# %%
full_noia = pd.read_csv('dataset/full-noia-contacts-modified.csv')

# %%
list_full_entities = get_entities_confidence_score('dataset/full-noia-contacts-modified.csv')

# %%
list_full_entities
# Out:
# {'Agency': {'entity': 'ORGANIZATION', 'confidence_score': 0.884},
#  'Department': {'entity': 'ORGANIZATION', 'confidence_score': 1.0},
#  'Name': {'entity': 'PERSON', 'confidence_score': 0.63},
#  'Title': {'entity': 'PERSON', 'confidence_score': 0.332},
#  'Room Number': {'entity': 'ORGANIZATION', 'confidence_score': 0.154},
#  'Street Address': None,
#  'City': {'entity': 'LOCATION', 'confidence_score': 0.33},
#  'State': None,
#  'Zip Code': {'entity': 'ZIPCODE', 'confidence_score': 1.0},
#  'Telephone': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.9},
#  'Fax': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.334},
#  'Email Address': {'entity': 'EMAIL_ADDRESS', 'confidence_score': 0.408},
#  'Website': {'entity': 'URL', 'confidence_score': 0.348},
#  'Online Request Form': None,
#  'Notes': {'entity': 'ORGANIZATION', 'confidence_score': 0.14},
#  'first_name': {'entity': 'PERSON', 'confidence_score': 0.532},
#  'last_number': None}

# %%
get_synthetic_dataset(full_noia, list_full_entities)
# Out:
# Column Telephone synthesized.
# Column Fax synthesized.
# Column Email Address synthesized.
# Column first_name synthesized.
# Column City synthesized.
# Column Website synthesized.
# Column Zip Code synthesized.
# Column Room Number not synthesized.
# Column Notes not synthesized.
# Column Agency not synthesized.
# Column Department not synthesized.
# Column Name not synthesized.
# Column Title not synthesized.
#                                                 Agency  \
# 0                       Agricultural Marketing Service
# 1                       Agricultural Marketing Service
# 2                       Agricultural Marketing Service
# 3                     Animal & Plant Health Inspection
# 4                     Animal & Plant Health Inspection
# ..                                                 ...
# 742  Office of Small and Disadvantaged Business Uti...
# 743  Office of Small and Disadvantaged Business Uti...
# 744                          I don't know which office
# 745                          I don't know which office
# 746                          I don't know which office
#
#                          Department             Name  \
# 0         Department of Agriculture  Gregory Bridges
# 1         Department of Agriculture              - -
# 2         Department of Agriculture    William Allen
# 3         Department of Agriculture      Tonya Woods
# 4         Department of Agriculture              - -
# ..                              ...              ...
# 742  Department of Veterans Affairs              - -
# 743  Department of Veterans Affairs      James Horan
# 744  Department of Veterans Affairs    Laurie Karnay
# 745  Department of Veterans Affairs              - -
# 746  Department of Veterans Affairs              - -
#
#                              Title                Room Number  \
# 0                     FOIA Officer  AG Stop 0202, Room 3521-S
# 1    FOIA Requester Service Center                        NaN
# 2              FOIA Public Liaison  AG Stop 0202, Room 3521-S
# 3                    FOIA Director                    Unit 50
# 4    FOIA Requester Service Center                        NaN
# ..                             ...                        ...
# 742  FOIA Requester Service Center                        NaN
# 743            FOIA Public Liaison                        NaN
# 744                 FOIA Team Lead              (005R1C) VACO
# 745  FOIA Requester Service Center                        NaN
# 746            FOIA Public Liaison                        NaN
#
#                    Street Address                City State Zip Code  \
# 0    1400 Independence Avenue, SW         West Teresa    DC    99207
# 1                             NaN        Simmonsmouth   NaN    74553
# 2    1400 Independence Avenue, SW         West Sandra    DC    06338
# 3                 4700 River Road  Lake Dustinchester    MD    53627
# 4                             NaN      Port Kaylaland   NaN    57045
# ..                            ...                 ...   ...      ...
# 742                           NaN    Lake Ashleymouth   NaN    97490
# 743                           NaN        Port Michael   NaN    22165
# 744        810 Vermont Avenue, NW         Lake Laurie    DC    38317
# 745                           NaN     Christopherbury   NaN    82083
# 746                           NaN        Petersonfurt   NaN    78017
#
#                 Telephone                    Fax              Email Address  \
# 0            273-567-9943  001-128-201-8863x2179         fkaufman@gmail.com
# 1        499-234-6613x123          (666)346-6886        raymond69@gmail.com
# 2            877.190.4642       001-717-848-5404  melissathomas@hotmail.com
# 3       (306)453-3610x467  +1-458-893-6375x31956         jjimenez@yahoo.com
# 4            003.412.6234           554-188-1404  hernandezmarcia@gmail.com
# ..                    ...                    ...                        ...
# 742   (500)754-3308x51486       579-375-6150x966       clinemegan@gmail.com
# 743    (404)916-1845x7900             7857836243  elizabethparker@yahoo.com
# 744     603.522.6082x8280          (759)147-5123    katelynnelson@gmail.com
# 745  +1-012-419-5842x5886     (372)059-9171x7908        hwhitaker@yahoo.com
# 746     170-926-6486x3998             5663096924           lisa71@yahoo.com
#
#                              Website  \
# 0    http://www.bowman-sullivan.com/
# 1            https://www.fisher.biz/
# 2           https://www.obrien.info/
# 3             https://www.burns.org/
# 4                https://larsen.biz/
# ..                               ...
# 742     https://www.stone-brown.com/
# 743              https://holden.biz/
# 744           https://patterson.biz/
# 745         https://www.brennan.com/
# 746         http://www.bradshaw.com/
#
#                                    Online Request Form  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    http://www.aphis.usda.gov/wps/portal/aphis/res...
# 4                                                  NaN
# ..                                                 ...
# 742                                                NaN
# 743                                                NaN
# 744                                                NaN
# 745                                                NaN
# 746                                                NaN
#
#                                                  Notes first_name last_number  \
# 0                                                  NaN   Benjamin     Bridges
# 1                                                  NaN      James           -
# 2                                                  NaN    Timothy       Allen
# 3                                                  NaN    Kathryn       Woods
# 4    * Please mail requests to FOIA.Officer@aphis.u...    Brandon           -
# ..                                                 ...        ...         ...
# 742                                                NaN      Paula           -
# 743                                                NaN    Timothy       Horan
# 744                                                NaN      Emily      Karnay
# 745                                                NaN       Jodi           -
# 746                                                NaN      Julie           -
#
#     first_name_gender
# 0                male
# 1             unknown
# 2                male
# 3              female
# 4             unknown
# ..                ...
# 742           unknown
# 743              male
# 744            female
# 745           unknown
# 746           unknown
#
# [747 rows x 18 columns]

# %%
df= pd.read_csv("dataset/contact_list_Austin.csv")

# %%
df
# Out:
#                                      Department  First Name       Last Name  \
# 0                                    Department  First Name       Last Name
# 1                        Animal Services Office        Joan  Hamilton-Huber
# 2                        Austin Code Department      Nathan         Brigmon
# 3                        Austin Code Department       Shawn         Lincoln
# 4                      Austin Convention Center       Chris       Hernandez
# ..                                          ...         ...             ...
# 139                    Austin Resource Recovery      Thomas      Montgomery
# 140                    Austin Resource Recovery      Thomas      Montgomery
# 141  Homeland Security and Emergency Management       Angel          Flores
# 142                  Office of the City Auditor       Tyler           Myers
# 143            Austin Transportation Department       Diana          Martin
#
#      Primary Contact                       E-Mail Address  Phone Number  \
# 0    Primary Contact                       E-Mail Address  Phone Number
# 1                NaN  Joan.Hamilton-Huber@austintexas.gov  512-978-0538
# 2                NaN       Nathan.Brigmon@austintexas.gov  512-974-6533
# 3                NaN        Shawn.Lincoln@austintexas.gov  512-974-9029
# 4                NaN      Chris.Hernandez@austintexas.gov  512-404-4031
# ..               ...                                  ...           ...
# 139               No    Thomas.Montgomery@austintexas.gov  512-974-6022
# 140               No    Thomas.Montgomery@austintexas.gov  512-974-6022
# 141              Yes         Angel.flores@austintexas.gov  512-974-0477
# 142              Yes          Tyler.Myers@austintexas.gov  512-974-2015
# 143              Yes         Diana.Martin@austintexas.gov  512-974-4079
#
#           Role
# 0         Role
# 1          NaN
# 2      Liaison
# 3          NaN
# 4      Liaison
# ..         ...
# 139  Publisher
# 140  Publisher
# 141    Liaison
# 142    Liaison
# 143    Liaison
#
# [144 rows x 7 columns]

# %%
list_df_entities = get_entities_confidence_score('dataset/contact_list_Austin.csv')

# %%
list_df_entities
# Out:
# {'Department': {'entity': 'ORGANIZATION',
#   'confidence_score': 0.8611111111111112},
#  'First Name': {'entity': 'PERSON', 'confidence_score': 0.7777777777777778},
#  'Last Name': {'entity': 'PERSON', 'confidence_score': 0.4027777777777778},
#  'Primary Contact': None,
#  'E-Mail Address': {'entity': 'EMAIL_ADDRESS',
#   'confidence_score': 0.8888888888888888},
#  'Phone Number': {'entity': 'PHONE_NUMBER',
#   'confidence_score': 0.8611111111111112},
#  'Role': None}

# %%
get_synthetic_dataset(df, list_df_entities)
# Out:
# Column Phone Number synthesized.
# Column E-Mail Address synthesized.
# Column First Name synthesized.
# Column Last Name synthesized.
# Column Department not synthesized.
#                                      Department First Name Last Name  \
# 0                                    Department      Casey     Clark
# 1                        Animal Services Office   Samantha      Boyd
# 2                        Austin Code Department    Gregory     Clark
# 3                        Austin Code Department      Derek   Shaffer
# 4                      Austin Convention Center    Michael  Marshall
# ..                                          ...        ...       ...
# 139                    Austin Resource Recovery    Jeffrey  Lawrence
# 140                    Austin Resource Recovery     Thomas     Jones
# 141  Homeland Security and Emergency Management     Andrew   Spencer
# 142                  Office of the City Auditor    Michael  Robinson
# 143            Austin Transportation Department    Michele   Sanchez
#
#      Primary Contact             E-Mail Address            Phone Number  \
# 0    Primary Contact         shelby56@gmail.com      (059)632-2714x9372
# 1                NaN      jameslisa@hotmail.com  001-310-813-7700x23658
# 2                NaN       wolfebrett@gmail.com     (173)461-9218x90076
# 3                NaN           ajones@yahoo.com      766.551.9286x65944
# 4                NaN      scastillo@hotmail.com   001-066-732-9165x6185
# ..               ...                        ...                     ...
# 139               No      melanie82@hotmail.com              9115360689
# 140               No   phillipsalas@hotmail.com        907-860-8093x176
# 141              Yes         nathan23@gmail.com            294.542.8449
# 142              Yes  gonzalezcolleen@yahoo.com     (311)325-8720x73990
# 143              Yes     jamesriggs@hotmail.com   +1-718-754-4968x37639
#
#           Role first_name_gender
# 0         Role           unknown
# 1          NaN            female
# 2      Liaison              male
# 3          NaN       mostly_male
# 4      Liaison       mostly_male
# ..         ...               ...
# 139  Publisher              male
# 140  Publisher              male
# 141    Liaison              male
# 142    Liaison       mostly_male
# 143    Liaison            female
#
# [144 rows x 8 columns]

# %%
df_table_order = pd.read_csv("dataset/table_order.csv")

# %%
df_table_order
# Out:
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber  \
# 0           10100    S18_1749               30     136.00                3
# 1           10100    S18_2248               50      55.09                2
# 2           10100    S18_4409               22      75.46                4
# 3           10100    S24_3969               49      35.29                1
# 4           10101    S18_2325               25     108.06                4
# ...           ...         ...              ...        ...              ...
# 2991        10425    S24_2300               49     127.79                9
# 2992        10425    S24_2840               31      31.82                5
# 2993        10425    S32_1268               41      83.79               11
# 2994        10425    S32_2509               11      50.32                6
# 2995        10425    S50_1392               18      94.92                2
#
#        orderDate requiredDate shippedDate      status                comments  \
# 0     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 1     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 2     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 3     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 4     2003-01-09   2003-01-18  2003-01-11     Shipped  Check on availability.
# ...          ...          ...         ...         ...                     ...
# 2991  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2992  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2993  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2994  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2995  2005-05-31   2005-06-07         NaN  In Process                     NaN
#
#       customerNumber                  customerName contactLastName  \
# 0                363  Online Diecast Creations Co.           Young
# 1                363  Online Diecast Creations Co.           Young
# 2                363  Online Diecast Creations Co.           Young
# 3                363  Online Diecast Creations Co.           Young
# 4                128          Blauer See Auto, Co.          Keitel
# ...              ...                           ...             ...
# 2991             119             La Rochelle Gifts         Labrune
# 2992             119             La Rochelle Gifts         Labrune
# 2993             119             La Rochelle Gifts         Labrune
# 2994             119             La Rochelle Gifts         Labrune
# 2995             119             La Rochelle Gifts         Labrune
#
#      contactFirstName              phone                  addressLine1  \
# 0             Dorothy         6035558647      2304 Long Airport Avenue
# 1             Dorothy         6035558647      2304 Long Airport Avenue
# 2             Dorothy         6035558647      2304 Long Airport Avenue
# 3             Dorothy         6035558647      2304 Long Airport Avenue
# 4              Roland  +49 69 66 90 2555                 Lyonerstr. 34
# ...               ...                ...                           ...
# 2991          Janine          40.67.8555  67, rue des Cinquante Otages
# 2992          Janine          40.67.8555  67, rue des Cinquante Otages
# 2993          Janine          40.67.8555  67, rue des Cinquante Otages
# 2994          Janine          40.67.8555  67, rue des Cinquante Otages
# 2995          Janine          40.67.8555  67, rue des Cinquante Otages
#
#      addressLine2       city state postalCode  country  \
# 0             NaN     Nashua    NH      62005      USA
# 1             NaN     Nashua    NH      62005      USA
# 2             NaN     Nashua    NH      62005      USA
# 3             NaN     Nashua    NH      62005      USA
# 4             NaN  Frankfurt   NaN      60528  Germany
# ...           ...        ...   ...        ...      ...
# 2991          NaN     Nantes   NaN      44000   France
# 2992          NaN     Nantes   NaN      44000   France
# 2993          NaN     Nantes   NaN      44000   France
# 2994          NaN     Nantes   NaN      44000   France
# 2995          NaN     Nantes   NaN      44000   France
#
#       salesRepEmployeeNumber  creditLimit productName       productLine  \
# 0                     1216.0       114200           *      Classic Cars
# 1                     1216.0       114200           *      Vintage Cars
# 2                     1216.0       114200           *      Vintage Cars
# 3                     1216.0       114200           *      Vintage Cars
# 4                     1504.0        59700           *  Trucks and Buses
# ...                      ...          ...         ...               ...
# 2991                  1370.0       118200           *      Vintage Cars
# 2992                  1370.0       118200           *      Classic Cars
# 2993                  1370.0       118200           *      Classic Cars
# 2994                  1370.0       118200           *      Classic Cars
# 2995                  1370.0       118200           *  Trucks and Buses
#
#      productScale              productVendor productDescription  \
# 0            1:10  Welly Diecast Productions                  *
# 1            1:24          Red Start Diecast                  *
# 2            1:32        Studio M Art Models                  *
# 3            1:32      Autoart Studio Design                  *
# 4            1:32      Autoart Studio Design                  *
# ...           ...                        ...                ...
# 2991         1:18  Welly Diecast Productions                  *
# 2992         1:18       Gearbox Collectibles                  *
# 2993         1:18            Min Lin Diecast                  *
# 2994         1:18          Red Start Diecast                  *
# 2995         1:10    Motor City Art Classics                  *
#
#       quantityInStock    buyPrice        MSRP
# 0              4823.0  103.125817  213.098062
# 1              2728.0   15.949021   33.802497
# 2              2685.0   21.882745   43.659252
# 3               550.0   16.061205   35.118038
# 4                24.0   25.660152   46.427639
# ...               ...         ...         ...
# 2991           6763.0   71.973408  117.440000
# 2992           9771.0   94.808700  152.250990
# 2993           9762.0   69.061199  138.994773
# 2994           8909.0   93.836843  208.542691
# 2995           4732.0  102.752781  210.966544
#
# [2996 rows x 31 columns]

# %%
list_df_table_order_entities = get_entities_confidence_score('dataset/table_order.csv')

# %%
list_df_table_order_entities
# Out:
# {'orderNumber': None,
#  'productCode': None,
#  'quantityOrdered': None,
#  'priceEach': None,
#  'orderLineNumber': None,
#  'orderDate': {'entity': 'DATE_TIME', 'confidence_score': 1.0},
#  'requiredDate': {'entity': 'DATE_TIME', 'confidence_score': 1.0},
#  'shippedDate': {'entity': 'DATE_TIME', 'confidence_score': 0.95},
#  'status': None,
#  'comments': None,
#  'customerNumber': None,
#  'customerName': {'entity': 'ORGANIZATION', 'confidence_score': 0.882},
#  'contactLastName': {'entity': 'PERSON', 'confidence_score': 0.536},
#  'contactFirstName': {'entity': 'PERSON', 'confidence_score': 0.816},
#  'phone': {'entity': 'PHONE_NUMBER', 'confidence_score': 0.574},
#  'addressLine1': {'entity': 'ADDRESS', 'confidence_score': 0.538},
#  'addressLine2': None,
#  'city': {'entity': 'LOCATION', 'confidence_score': 0.78},
#  'state': None,
#  'postalCode': {'entity': 'ZIPCODE', 'confidence_score': 1.0},
#  'country': {'entity': 'LOCATION', 'confidence_score': 1.0},
#  'salesRepEmployeeNumber': None,
#  'creditLimit': None,
#  'productName': None,
#  'productLine': None,
#  'productScale': None,
#  'productVendor': {'entity': 'ORGANIZATION', 'confidence_score': 0.456},
#  'productDescription': None,
#  'quantityInStock': None,
#  'buyPrice': None,
#  'MSRP': None}

# %%
get_synthetic_dataset(df_table_order, list_df_table_order_entities)
# Out:
# Column addressLine1 synthesized.
# Column phone synthesized.
# Column contactFirstName synthesized.
# Column contactLastName synthesized.
# Column city synthesized.
# Column postalCode synthesized.
# Column country synthesized.
# Column orderDate not synthesized.
# Column requiredDate not synthesized.
# Column shippedDate not synthesized.
# Column customerName not synthesized.
# Column productVendor not synthesized.
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber  \
# 0           10100    S18_1749               30     136.00                3
# 1           10100    S18_2248               50      55.09                2
# 2           10100    S18_4409               22      75.46                4
# 3           10100    S24_3969               49      35.29                1
# 4           10101    S18_2325               25     108.06                4
# ...           ...         ...              ...        ...              ...
# 2991        10425    S24_2300               49     127.79                9
# 2992        10425    S24_2840               31      31.82                5
# 2993        10425    S32_1268               41      83.79               11
# 2994        10425    S32_2509               11      50.32                6
# 2995        10425    S50_1392               18      94.92                2
#
#        orderDate requiredDate shippedDate      status                comments  \
# 0     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 1     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 2     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 3     2003-01-06   2003-01-13  2003-01-10     Shipped                     NaN
# 4     2003-01-09   2003-01-18  2003-01-11     Shipped  Check on availability.
# ...          ...          ...         ...         ...                     ...
# 2991  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2992  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2993  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2994  2005-05-31   2005-06-07         NaN  In Process                     NaN
# 2995  2005-05-31   2005-06-07         NaN  In Process                     NaN
#
#       customerNumber                  customerName contactLastName  \
# 0                363  Online Diecast Creations Co.          Cuevas
# 1                363  Online Diecast Creations Co.           Davis
# 2                363  Online Diecast Creations Co.         Mccarty
# 3                363  Online Diecast Creations Co.           Smith
# 4                128          Blauer See Auto, Co.          Mathis
# ...              ...                           ...             ...
# 2991             119             La Rochelle Gifts       Blackburn
# 2992             119             La Rochelle Gifts        Hamilton
# 2993             119             La Rochelle Gifts           Gomez
# 2994             119             La Rochelle Gifts          Martin
# 2995             119             La Rochelle Gifts          Dunlap
#
#      contactFirstName                 phone                    addressLine1  \
# 0             Tiffany         (869)381-4786      0823 Wilson Mews Suite 212
# 1             Jasmine     (275)991-1174x673  9438 Martinez Radial Suite 198
# 2            Kimberly            9934748202    1988 Robinson Grove Apt. 888
# 3             Breanna         (007)888-5752   65754 Kennedy Garden Apt. 384
# 4                 Ian          477-231-7444       353 Mcneil Lane Suite 313
# ...               ...                   ...                             ...
# 2991           Andrew      059-866-8813x234              6615 Swanson Mills
# 2992         Mckenzie  +1-500-852-8931x9788  86886 Lopez Turnpike Suite 781
# 2993           Brenda         (569)907-7609     751 Angela Rapids Suite 167
# 2994             Dawn   (845)194-5875x63449             28246 Steven Island
# 2995            Erika      001-206-358-5791             11709 Vaughn Brooks
#
#      addressLine2                city state postalCode  \
# 0             NaN         Newmanhaven    NH      68284
# 1             NaN      Stephenborough    NH      93462
# 2             NaN        Kathleenview    NH      94362
# 3             NaN   West Michellefurt    NH      73843
# 4             NaN        North Joshua   NaN      04294
# ...           ...                 ...   ...        ...
# 2991          NaN           Emilytown   NaN      36440
# 2992          NaN  Lake Katherinefurt   NaN      71481
# 2993          NaN          Kristinton   NaN      30199
# 2994          NaN          Shorthaven   NaN      04237
# 2995          NaN   Port Michaelmouth   NaN      76222
#
#                                            country  salesRepEmployeeNumber  \
# 0                             Netherlands Antilles                  1216.0
# 1                                           Greece                  1216.0
# 2             United States Minor Outlying Islands                  1216.0
# 3                                     South Africa                  1216.0
# 4                                   Czech Republic                  1504.0
# ...                                            ...                     ...
# 2991                                        Uganda                  1370.0
# 2992                                      Slovenia                  1370.0
# 2993                                        Cyprus                  1370.0
# 2994                      Northern Mariana Islands                  1370.0
# 2995  South Georgia and the South Sandwich Islands                  1370.0
#
#       creditLimit productName       productLine productScale  \
# 0          114200           *      Classic Cars         1:10
# 1          114200           *      Vintage Cars         1:24
# 2          114200           *      Vintage Cars         1:32
# 3          114200           *      Vintage Cars         1:32
# 4           59700           *  Trucks and Buses         1:32
# ...           ...         ...               ...          ...
# 2991       118200           *      Vintage Cars         1:18
# 2992       118200           *      Classic Cars         1:18
# 2993       118200           *      Classic Cars         1:18
# 2994       118200           *      Classic Cars         1:18
# 2995       118200           *  Trucks and Buses         1:10
#
#                   productVendor productDescription  quantityInStock  \
# 0     Welly Diecast Productions                  *           4823.0
# 1             Red Start Diecast                  *           2728.0
# 2           Studio M Art Models                  *           2685.0
# 3         Autoart Studio Design                  *            550.0
# 4         Autoart Studio Design                  *             24.0
# ...                         ...                ...              ...
# 2991  Welly Diecast Productions                  *           6763.0
# 2992       Gearbox Collectibles                  *           9771.0
# 2993            Min Lin Diecast                  *           9762.0
# 2994          Red Start Diecast                  *           8909.0
# 2995    Motor City Art Classics                  *           4732.0
#
#         buyPrice        MSRP first_name_gender
# 0     103.125817  213.098062            female
# 1      15.949021   33.802497            female
# 2      21.882745   43.659252            female
# 3      16.061205   35.118038            female
# 4      25.660152   46.427639              male
# ...          ...         ...               ...
# 2991   71.973408  117.440000           unknown
# 2992   94.808700  152.250990           unknown
# 2993   69.061199  138.994773           unknown
# 2994   93.836843  208.542691           unknown
# 2995  102.752781  210.966544           unknown
#
# [2996 rows x 32 columns]

# %%
import gender_guesser.detector as gender

# %%
detector = gender.Detector(case_sensitive=False)

# %%
first_name_gender = []
for name in full_noia['Name']:
    first_name_gender.append(detector.get_gender(name))

# %%
first_name_gender
# Out:
# ['unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown']

# %%
from faker import Faker

if len(list_entities) > 0:
    try:
        faker = Faker()
        loc_cols = [[i, list_entities[i]['entity']] for i in list_entities if list_entities[i] is not None]
        
        adrs = [i[0] for i in loc_cols if i[1] == 'ADDRESS']
        for i in adrs:
            synth[i] = [faker.street_address() for i in range(synth.shape[0])]

        phone = [i[0] for i in loc_cols if i[1] == 'PHONE_NUMBER']
        for i in phone:
            synth[i] = [faker.phone_number() for i in range(synth.shape[0])]

        
    except:
        print('Something went wrong while create fake PIIs')
